# %%
#ipython functions
# %autocall 2
# %matplotlib notebook
# %matplotlib inline
#system functions
import sys
import re
import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)
#pandas, matlib, numpy and the whole ecosystem of python science dealies
import pandas as pd
import scipy as sp
import numpy as np
from numpy import arange,array,ones
from scipy import stats
import matplotlib.pyplot as plt
# Out:
# Automatic calling is: Full

# %%
occ=pd.read_excel("./DataSets/BLS/state_M2015_dl.xlsx")

# %%
occ=occ.loc[occ['STATE'] == 'Michigan']

# %%
occ
# Out:
#        AREA  ST     STATE OCC_CODE  \
# 15762    26  MI  Michigan  00-0000
# 15763    26  MI  Michigan  11-0000
# 15764    26  MI  Michigan  11-1011
# 15765    26  MI  Michigan  11-1021
# 15766    26  MI  Michigan  11-1031
# 15767    26  MI  Michigan  11-2011
# 15768    26  MI  Michigan  11-2021
# 15769    26  MI  Michigan  11-2022
# 15770    26  MI  Michigan  11-2031
# 15771    26  MI  Michigan  11-3011
# 15772    26  MI  Michigan  11-3021
# 15773    26  MI  Michigan  11-3031
# 15774    26  MI  Michigan  11-3051
# 15775    26  MI  Michigan  11-3061
# 15776    26  MI  Michigan  11-3071
# 15777    26  MI  Michigan  11-3111
# 15778    26  MI  Michigan  11-3121
# 15779    26  MI  Michigan  11-3131
# 15780    26  MI  Michigan  11-9013
# 15781    26  MI  Michigan  11-9021
# 15782    26  MI  Michigan  11-9031
# 15783    26  MI  Michigan  11-9032
# 15784    26  MI  Michigan  11-9033
# 15785    26  MI  Michigan  11-9039
# 15786    26  MI  Michigan  11-9041
# ...
