# %%
#ipython functions
# %autocall 2
# %matplotlib notebook
# %matplotlib inline
#system functions
import sys
import re
import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)
#pandas, matlib, numpy and the whole ecosystem of python science dealies
import pandas as pd
pd.set_option('display.max_columns', 500)
import scipy as sp
import numpy as np
from numpy import arange,array,ones
from scipy import stats
import matplotlib.pyplot as plt
# Out:
# Automatic calling is: Full

# %%
occ=pd.read_excel("./DataSets/BLS/state_M2015_dl.xlsx")

# %%
occ=occ.loc[occ['STATE'] == 'Michigan']
occ=occ[occ.OCC_CODE.str.contains('^15')]

# %%
occ.reset_index
occ.drop(occ.index[0,1,3,8])
# Out:
# -> occ.reset_index()
#     index  AREA  ST     STATE OCC_CODE  \
# 0   15830    26  MI  Michigan  15-0000
# 1   15831    26  MI  Michigan  15-1111
# 2   15832    26  MI  Michigan  15-1121
# 3   15833    26  MI  Michigan  15-1122
# 4   15834    26  MI  Michigan  15-1131
# 5   15835    26  MI  Michigan  15-1132
# 6   15836    26  MI  Michigan  15-1133
# 7   15837    26  MI  Michigan  15-1134
# 8   15838    26  MI  Michigan  15-1141
# 9   15839    26  MI  Michigan  15-1142
# 10  15840    26  MI  Michigan  15-1143
# 11  15841    26  MI  Michigan  15-1151
# 12  15842    26  MI  Michigan  15-1152
# 13  15843    26  MI  Michigan  15-1199
# 14  15844    26  MI  Michigan  15-2011
# 15  15845    26  MI  Michigan  15-2021
# 16  15846    26  MI  Michigan  15-2031
# 17  15847    26  MI  Michigan  15-2041
#
#                                        OCC_TITLE OCC_GROUP TOT_EMP EMP_PRSE  \
# 0          Computer and Mathematical Occupations     major  102330      2.8
# 1   Computer and Information Research Scientists  detailed     360      8.7
# 2                      Computer Systems Analysts  detailed   14030        7
# 3                  Information Security Analysts  detailed    2090     26.4
# 4                           Computer Programmers  detailed    4910      7.4
# 5              Software Developers, Applications  detailed   17260      5.5
# 6          Software Developers, Systems Software  detailed   11610      9.8
# 7                                 Web Developers  detailed    2600      8.1
# 8                        Database Administrators  detailed    2570      8.5
# 9    Network and Computer Systems Administrators  detailed    9080        6
# 10                   Computer Network Architects  detailed    2170     11.2
# 11             Computer User Support Specialists  detailed   19760      5.6
# 12          Computer Network Support Specialists  detailed    6250      8.4
# 13               Computer Occupations, All Other  detailed    7050      3.4
# 14                                     Actuaries  detailed     370     24.3
# 15                                Mathematicians  detailed      60     27.6
# 16                  Operations Research Analysts  detailed    1650      5.9
# 17                                 Statisticians  detailed     500     12.9
#
#    JOBS_1000 LOC_Q H_MEAN  A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN H_PCT75  \
